# %% [markdown]
# In this project I demonstrate my ability to use self-made functions during my course to extract useful genome features from a text file. The functions can be found in "dna_tools.py". The file Dolphin_genes_mart_export.text is too big to be uploaded in github, I will send it by mail if it's necessary.

# %%
from dna_tools import get_genome_data
from dna_tools import show_genome_features
    
    

dol_genes = get_genome_data(use_file = "Dolphin_genes_mart_export.txt")
show_genome_features(dol_genes)
# Out:
# This genome consists of 21265 genes
# The average gene length is 35267.378039031275 basepairs
# The average coding region is 1343.1594639078298 basepairs
